# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
from itertools import combinations

# %%
#df_genome_scores = pd.read_csv("/content/drive/MyDrive/MovieLensRecommendationEngine/data/genome-scores.csv")
#df_genome_tags = pd.read_csv("/content/drive/MyDrive/MovieLensRecommendationEngine/data/genome-tags.csv")
df_links = pd.read_csv("/content/drive/MyDrive/MovieLensRecommendationEngine/data/links.csv")
df_movies = pd.read_csv("/content/drive/MyDrive/MovieLensRecommendationEngine/data/movies.csv")
df_ratings = pd.read_csv("/content/drive/MyDrive/MovieLensRecommendationEngine/data/ratings.csv")
df_tags = pd.read_csv("/content/drive/MyDrive/MovieLensRecommendationEngine/data/tags.csv")

# %%
df_movies.head(5)
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
high_ratings=df_ratings[ (df_ratings['userId']==31) & (df_ratings['rating']==5.0)]
high_r=list(high_ratings['movieId'])
print(high_r)
list(df_movies[df_movies['movieId'].isin(high_r)]['title'])
# Out:
# [1, 377, 588, 648, 733, 784, 912, 1036, 1057, 1197, 1278, 1282, 1361, 1363, 1391, 5060]
# 0                                        Toy Story (1995)
# 334                                          Speed (1994)
# 506                                        Aladdin (1992)
# 546                            Mission: Impossible (1996)
# 592                                      Rock, The (1996)
# 619                                 Cable Guy, The (1996)
# 694                                     Casablanca (1942)
# 793                                       Die Hard (1988)
# 808                       Everyone Says I Love You (1996)
# 899                            Princess Bride, The (1987)
# 977                             Young Frankenstein (1974)
# 981                                       Fantasia (1940)
# 1048    Paradise Lost: The Child Murders at Robin Hood...
# 1049                          Preacher's Wife, The (1996)
# 1071                                 Mars Attacks! (1996)
# 3673                         M*A*S*H (a.k.a. MASH) (1970)
# Name: title, dtype: object

# %%
#df_movies.head()
len(df_tags['tag'].unique())
# Out:
# 1589

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#can change upper limit of range to increase number of genres /increase dimensions of the vector(no of genres considered as a column) considered
tf = TfidfVectorizer(analyzer=lambda s: (c for i in range(1,4)
                                             for c in combinations(s.split('|'), r=i)))
tfidf_matrix = tf.fit_transform(df_movies['genres'])
#tfidf_matrix.shape
pd.DataFrame(tfidf_matrix.todense(), columns=tf.get_feature_names(), index=df_movies.title).sample(5, axis=1).sample(10, axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                                 (Action, Drama, Western)  ...  (Adventure, Children, Western)
# title                                                                     ...
# Fear X (2003)                                                        0.0  ...                             0.0
# Lynne Koplitz: Hormonal Beast (2017)                                 0.0  ...                             0.0
# Cinema Paradiso (Nuovo cinema Paradiso) (1989)                       0.0  ...                             0.0
# Silent Hill (2006)                                                   0.0  ...                             0.0
# Charlie Bartlett (2007)                                              0.0  ...                             0.0
# Bowfinger (1999)                                                     0.0  ...                             0.0
# Pitfall (Otoshiana) (1962)                                           0.0  ...                             0.0
# Premonition (2007)                                                   0.0  ...                             0.0
# Enemy (2013)                                                         0.0  ...                             0.0
# Young Adult (2011)                                                   0.0  ...                             0.0
#
# [10 rows x 5 columns]

# %%
#pd.DataFrame(tfidf_matrix.todense(), columns=tf.get_feature_names(), index=df_movies.title).sample(10, axis=1).sample(10, axis=0)
vectors=pd.DataFrame(tfidf_matrix.todense(), columns=tf.get_feature_names(), index=df_movies.title)
print(vectors)
#print(vectors.mean(axis=0))
# Out:
#                                            ((no genres listed),)  ...  (Western, IMAX)
# title                                                             ...
# Toy Story (1995)                                             0.0  ...              0.0
# Jumanji (1995)                                               0.0  ...              0.0
# Grumpier Old Men (1995)                                      0.0  ...              0.0
# Waiting to Exhale (1995)                                     0.0  ...              0.0
# Father of the Bride Part II (1995)                           0.0  ...              0.0
# ...                                                          ...  ...              ...
# Black Butler: Book of the Atlantic (2017)                    0.0  ...              0.0
# No Game No Life: Zero (2017)                                 0.0  ...              0.0
# Flint (2017)                                                 0.0  ...              0.0
# Bungo Stray Dogs: Dead Apple (2018)                          0.0  ...              0.0
# Andrew Dice Clay: Dice Rules (1991)                          0.0  ...              0.0
#
# [9742 rows x 783 columns]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
pd.DataFrame(tfidf_matrix.todense(), columns=tf.get_feature_names(), index=df_movies.title).sample(20, axis=1).sample(40, axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                                     (Documentary, Horror)  ...  (Comedy, Sci-Fi, War)
# title                                                                      ...
# Ace Ventura: When Nature Calls (1995)                                 0.0  ...                    0.0
# Meet Me in St. Louis (1944)                                           0.0  ...                    0.0
# Fugitive, The (1947)                                                  0.0  ...                    0.0
# Blue Lagoon, The (1980)                                               0.0  ...                    0.0
# Moana (2016)                                                          0.0  ...                    0.0
# Hunger (2008)                                                         0.0  ...                    0.0
# Slumber Party Massacre II (1987)                                      0.0  ...                    0.0
# Theremin: An Electronic Odyssey (1993)                                0.0  ...                    0.0
# Rough Magic (1995)                                                    0.0  ...                    0.0
# Revenge of the Nerds II: Nerds in Paradise (1987)                     0.0  ...                    0.0
# Ruling Class, The (1972)                                              0.0  ...                    0.0
# Levity (2003)                                                         0.0  ...                    0.0
# Wit (2001)                                                            0.0  ...                    0.0
# Buddy Boy (1999)                                                      0.0  ...                    0.0
# Love Letter, The (1999)                                               0.0  ...                    0.0
# Zone 39 (1997)                                                        0.0  ...                    0.0
# Akira (1988)                                                          0.0  ...                    0.0
# Marathon Man (1976)                                                   0.0  ...                    0.0
# Man Who Knew Too Much, The (1956)                                     0.0  ...                    0.0
# Smokey and the Bandit III (1983)                                      0.0  ...                    0.0
# Reckless (1995)                                                       0.0  ...                    0.0
# Alphaville (Alphaville, une étrange aventure de...                    0.0  ...                    0.0
# Love, Simon (2018)                                                    0.0  ...                    0.0
# Tarantula (1955)                                                      0.0  ...                    0.0
# Monty Python's The Meaning of Life (1983)                             0.0  ...                    0.0
# Children of a Lesser God (1986)                                       0.0  ...                    0.0
# Mother! (2017)                                                        0.0  ...                    0.0
# Life Less Ordinary, A (1997)                                          0.0  ...                    0.0
# Lantana (2001)                                                        0.0  ...                    0.0
# Betsy's Wedding (1990)                                                0.0  ...                    0.0
# Inventing the Abbotts (1997)                                          0.0  ...                    0.0
# Stitch! The Movie (2003)                                              0.0  ...                    0.0
# Contender, The (2000)                                                 0.0  ...                    0.0
# Pollyanna (1960)                                                      0.0  ...                    0.0
# They Came Together (2014)                                             0.0  ...                    0.0
# Teenage Mutant Ninja Turtles (2014)                                   0.0  ...                    0.0
# Antichrist (2009)                                                     0.0  ...                    0.0
# Mummy, The (1999)                                                     0.0  ...                    0.0
# Paradise Road (1997)                                                  0.0  ...                    0.0
# Donnie Darko (2001)                                                   0.0  ...                    0.0
#
# [40 rows x 20 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
cosine_sim_df = pd.DataFrame(cosine_sim, index=df_movies['title'], columns=df_movies['title'])
print('Shape:', cosine_sim_df.shape)
cosine_sim_df.sample(5, axis=1).round(2)
# Out:
# Shape: (9742, 9742)
# title                                      Certified Copy (Copie conforme) (2010)  ...  Lynne Koplitz: Hormonal Beast (2017)
# title                                                                              ...
# Toy Story (1995)                                                             0.00  ...                                  0.08
# Jumanji (1995)                                                               0.00  ...                                  0.00
# Grumpier Old Men (1995)                                                      0.00  ...                                  0.40
# Waiting to Exhale (1995)                                                     0.22  ...                                  0.24
# Father of the Bride Part II (1995)                                           0.00  ...                                  1.00
# ...                                                                           ...  ...                                   ...
# Black Butler: Book of the Atlantic (2017)                                    0.00  ...                                  0.11
# No Game No Life: Zero (2017)                                                 0.00  ...                                  0.17
# Flint (2017)                                                                 1.00  ...                                  0.00
# Bungo Stray Dogs: Dead Apple (2018)                                          0.00  ...                                  0.00
# Andrew Dice Clay: Dice Rules (1991)                                          0.00  ...                                  1.00
#
# [9742 rows x 5 columns]

# %%
def genre_recommendations(i, M, items, k=10):
    """
    Recommends movies based on a similarity dataframe

    Parameters
    ----------
    i : str
        Movie (index of the similarity dataframe)
    M : pd.DataFrame
        Similarity dataframe, symmetric, with movies as indices and columns
    items : pd.DataFrame
        Contains both the title and some other features used to define similarity
    k : int
        Amount of recommendations to return

    """
    
    ix = M.loc[:,i].to_numpy().argpartition(range(-1,-k,-1))
    print("ix",ix,ix.shape)
    #print('z',z)
    closest = M.columns[ix[-1:-(k+2):-1]]
    closest = closest.drop(i, errors='ignore')
    return pd.DataFrame(closest).merge(items).head(k)

# %%
def genre_recommendations1(user, M, items, k=10):
    """
    Recommends movies based on a similarity dataframe

    Parameters
    ----------
    i : str
        Movie (index of the similarity dataframe)
    M : pd.DataFrame
        Similarity dataframe, symmetric, with movies as indices and columns
    items : pd.DataFrame
        Contains both the title and some other features used to define similarity
    k : int
        Amount of recommendations to return

    """
    high_ratings=df_ratings[ (df_ratings['userId']==user) & (df_ratings['rating']==5.0)]
    high_r=list(high_ratings['movieId'])
    print(high_r)
    i=list(df_movies[df_movies['movieId'].isin(high_r)]['title'])
    print('i',i)
    ix = M.loc[:,i[0]]#.to_numpy().argpartition(range(-1,-k,-1))
    
    for x in range(1,len(i)):
      ix+=M.loc[:,i[x]].to_numpy().argpartition(range(-1,-k,-1))
      #ix+=a
      #print(a,a.shape,ix.shape)
    ix=ix.sort_values(ascending=False)
    #print("ix",ix.shape,'\n',ix.iloc[:20])
    #print('z',z)
    z= ix.head(10).index.values
    print(df_movies[df_movies['title'].isin(z)])
    return df_movies[df_movies['title'].isin(z)]
    #ix=ix.to_numpy().argpartition(range(-1,-k,-1))
    #closest = M.columns[ix[-1:-(k+2):-1]]
    #closest = closest.drop(i, errors='ignore')
    #return pd.DataFrame(closest).merge(items).head(k)

# %%
df_movies[df_movies['title'].str.startswith('Pulp')]
# Out:
#      movieId                title                       genres
# 257      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller

# %%
#genre_recommendations('2001: A Space Odyssey (1968)', cosine_sim_df, df_movies[['title', 'genres']])
genre_recommendations1(31, cosine_sim_df, df_movies[['title', 'genres']])
#genre_recommendations1(['Inglourious Basterds (2009)','Pulp Fiction (1994)'], cosine_sim_df, df_movies[['title', 'genres']])
#genre_recommendations1(['Chronicles of Narnia: Prince Caspian, The (2008)','Hobbit: The Desolation of Smaug, The (2013)'], cosine_sim_df, df_movies[['title', 'genres']])
# Out:
# [1, 377, 588, 648, 733, 784, 912, 1036, 1057, 1197, 1278, 1282, 1361, 1363, 1391, 5060]
# i ['Toy Story (1995)', 'Speed (1994)', 'Aladdin (1992)', 'Mission: Impossible (1996)', 'Rock, The (1996)', 'Cable Guy, The (1996)', 'Casablanca (1942)', 'Die Hard (1988)', 'Everyone Says I Love You (1996)', 'Princess Bride, The (1987)', 'Young Frankenstein (1974)', 'Fantasia (1940)', 'Paradise Lost: The Child Murders at Robin Hood Hills (1996)', "Preacher's Wife, The (1996)", 'Mars Attacks! (1996)', 'M*A*S*H (a.k.a. MASH) (1970)']
#      movieId                                  title  genres
# 4          5     Father of the Bride Part II (1995)  Comedy
# 17        18                      Four Rooms (1995)  Comedy
# 18        19  Ace Ventura: When Nature Calls (1995)  Comedy
# 58        65                        Bio-Dome (1996)  Comedy
# 61        69                          Friday (1995)  Comedy
# 79        88                     Black Sheep (1996)  Comedy
# 90       102                       Mr. Wrong (1996)  Comedy
# 92       104                   Happy Gilmore (1996)  Comedy
# 104      119         Steal Big, Steal Little (1995)  Comedy
# 108      125          Flirting With Disaster (1996)  Comedy
#      movieId                                  title  genres
# 4          5     Father of the Bride Part II (1995)  Comedy
# 17        18                      Four Rooms (1995)  Comedy
# 18        19  Ace Ventura: When Nature Calls (1995)  Comedy
# 58        65                        Bio-Dome (1996)  Comedy
# 61        69                          Friday (1995)  Comedy
# 79        88                     Black Sheep (1996)  Comedy
# 90       102                       Mr. Wrong (1996)  Comedy
# 92       104                   Happy Gilmore (1996)  Comedy
# 104      119         Steal Big, Steal Little (1995)  Comedy
# 108      125          Flirting With Disaster (1996)  Comedy
